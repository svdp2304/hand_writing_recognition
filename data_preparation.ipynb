# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import cv2
import glob
import pickle

# %%
train_dir="C:/Users/pc/Desktop/hand_writing_recognition/data/dataset_signature_final/dataset1/real"

# %%
img = plt.imread('C:/Users/pc/Desktop/hand_writing_recognition/data/dataset_signature_final/dataset1/real/00100001.PNG')
plt.imshow(img)

# %%
SIZE = 224

# %%
data_names = []

data_ = []
labels = []

for per in os.listdir('C:/Users/pc/Desktop/hand_writing_recognition/data/dataset_signature_final/dataset1/real'):
    for data in glob.glob('C:/Users/pc/Desktop/hand_writing_recognition/data/dataset_signature_final/dataset1/real/'+per):
        
        data_names.append(data)
        img = cv2.imread(data)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = cv2.resize(img, (SIZE,SIZE))
        data_.append([img])
        if per[-1]=='g':
            labels.append(np.array(1))
        else:
            labels.append(np.array(0))

data_ = np.array(data_)/255.0
labels = np.array(labels)

# %%
data_
# Out:
# array([[[[[0.95686275, 0.98823529, 0.98823529],
#           [0.95686275, 0.98823529, 0.98823529],
#           [0.95686275, 0.98823529, 0.98823529],
#           ...,
#           [0.94117647, 0.98431373, 0.99215686],
#           [0.94509804, 0.98431373, 0.99215686],
#           [0.94901961, 0.98823529, 0.99215686]],
#
#          [[0.95686275, 0.98823529, 0.98823529],
#           [0.95686275, 0.98823529, 0.98823529],
#           [0.95686275, 0.98823529, 0.98823529],
#           ...,
#           [0.94117647, 0.98431373, 0.99215686],
#           [0.94509804, 0.98431373, 0.99215686],
#           [0.94901961, 0.98823529, 0.99215686]],
#
#          [[0.95686275, 0.98823529, 0.98823529],
#           [0.95686275, 0.98823529, 0.98823529],
#           [0.95686275, 0.98823529, 0.98823529],
#           ...,
#           [0.94117647, 0.98431373, 0.99215686],
#           [0.94509804, 0.98431373, 0.99215686],
#           [0.94901961, 0.98823529, 0.99215686]],
#
#          ...,
#
# ...

# %%
for per in os.listdir('C:/Users/pc/Desktop/hand_writing_recognition/data/dataset_signature_final/dataset1/real'):
    print('C:/Users/pc/Desktop/hand_writing_recognition/data/dataset_signature_final/dataset1/real/'+per)
# Out:
# C:/Users/pc/Desktop/hand_writing_recognition/data/dataset_signature_final/dataset1/real/00100001.png
# C:/Users/pc/Desktop/hand_writing_recognition/data/dataset_signature_final/dataset1/real/00101001.png
# C:/Users/pc/Desktop/hand_writing_recognition/data/dataset_signature_final/dataset1/real/00102001.png
# C:/Users/pc/Desktop/hand_writing_recognition/data/dataset_signature_final/dataset1/real/00103001.png
# C:/Users/pc/Desktop/hand_writing_recognition/data/dataset_signature_final/dataset1/real/00104001.png
# C:/Users/pc/Desktop/hand_writing_recognition/data/dataset_signature_final/dataset1/real/00200002.png
# C:/Users/pc/Desktop/hand_writing_recognition/data/dataset_signature_final/dataset1/real/00201002.png
# C:/Users/pc/Desktop/hand_writing_recognition/data/dataset_signature_final/dataset1/real/00202002.png
# C:/Users/pc/Desktop/hand_writing_recognition/data/dataset_signature_final/dataset1/real/00203002.png
# ...
